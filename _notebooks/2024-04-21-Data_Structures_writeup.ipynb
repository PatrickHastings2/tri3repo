# %% [markdown]
# ---
# comments: true
# layout: post
# title: Data Structures Write up
# description:
# courses: { compsci: {week: 26} }
# type: hacks
# ---

# %% [markdown]
# ## Collections Blog Python Model code and SQLite Database.
#
# - From VSCode using SQLite3 Editor, show your unique collection/table in database, display rows and columns in the table of the SQLite database.

# %% [markdown]
# <iframe src="https://drive.google.com/file/d/1PPFnb3mn7pNKYKNywzUx02tcpS-2p1m0/preview" width="640" height="480" allow="autoplay"></iframe>

# %% [markdown]
# <img width="986" alt="Screenshot 2024-04-21 at 6 29 50 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/94b2f24e-7b98-4af6-ba3c-87ab11628e7b">

# %% [markdown]
# - Opening text file that contains all text data and line by line reads it and organizes the values in to a database
#
#     - The code sets up a structure to organize and store text data into a database.

# %% [markdown]
# <img width="999" alt="Screenshot 2024-04-21 at 6 23 50 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/7a6314be-99cf-4890-897f-ea0bed5097c1">
#
# - Show your unique code that was created to initialize table and create test data from VSCode model.
#     - The function reads a text file line by line, interprets each line as a dictionary, and then stores each dictionary's values into a database as a new entry.

# %% [markdown]
# ## Lists and Dictionaries

# %% [markdown]
# <img width="391" alt="Screenshot 2024-05-08 at 10 37 54 AM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/aa693a6d-e081-4e8f-bd56-98d8cfbdfee4">

# %% [markdown]
# - "args" is a dictionary containing the parsed request arguments.

# %% [markdown]
# <img width="303" alt="Screenshot 2024-05-08 at 10 40 08 AM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/e38b2723-5b80-4a41-b25b-8a0efa332b04">

# %% [markdown]
# - This line returns a dictionary generated by the to_dict() method

# %% [markdown]
# <img width="302" alt="Screenshot 2024-05-08 at 10 44 27 AM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/ae091c98-61a7-40c9-b1c8-37214237c707">

# %% [markdown]
# - This line constructs a list of dictionaries, with each dictionary representing the Data object attributes.

# %% [markdown]
# - Show a list as extracted from database as Python objects in VSCode using Debugger.

# %% [markdown]
# <img width="420" alt="Screenshot 2024-05-08 at 10 47 44 AM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/318dbab1-a335-4899-8cda-f9d21ec51966">

# %% [markdown]
# - In the get method of the DataListAPI class,I am querying the database to fetch all Data objects using db.session.query(Data).all(). This returns a list of data objects. Then, i'm using a list comprehension to iterate over this list (for d in data) and convert each data object into a dictionary using the to_dict() method (d.to_dict()). Finally,the code is returning this list of dictionaries as the response.

# %% [markdown]
# ## APIs and JSON
#
# - In VSCode, show Python API code definition for request and response using GET, POST, UPDATE methods. Discuss algorithmic condition used to direct request to appropriate Python method based on request method.

# %% [markdown]
# <img width="317" alt="Screenshot 2024-04-24 at 10 28 08 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/eda1d4ce-7b30-45c6-bd91-41aa43505ec2">

# %% [markdown]
# - A resource is included in the API at the suitable URL.
# - When a request is dispatched to this URL, the corresponding function is invoked based on the type of request sent.

# %% [markdown]
# ## Python API code definition for request and response using GET, POST, UPDATE methods in VSCode

# %% [markdown]
# <img width="394" alt="Screenshot 2024-04-21 at 6 59 45 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/e34297f2-cf33-46b5-be71-83754bf6b30a">

# %% [markdown]
# - Show algorithmic conditions used to validate data on a POST condition in VSCode.

# %% [markdown]
# <img width="320" alt="Screenshot 2024-04-23 at 11 08 05 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/3895474b-f5f2-4c35-95c4-61d218165aab">

# %% [markdown]
# <img width="328" alt="Screenshot 2024-04-21 at 6 50 34 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/9ecb04b0-6fc0-4ca5-80b3-f547dbd14c2f">

# %% [markdown]
# -The code processes incoming data for storage in a database and checks to make sure no required information is missing. If data is correct, it saves it; if not, it sends an error message.

# %% [markdown]
# <img width="530" alt="Screenshot 2024-04-21 at 7 01 19 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/b94c5240-42a5-4d6f-815e-9af260454bdd">

# %% [markdown]
# - The code snippet is designed to update a database entry. It first checks that all necessary information is provided, and if anything is missing, it reports an error; otherwise, it proceeds to update the entry with the new data.

# %% [markdown]
# ## Show URL request and Body requirements for GET, POST, and UPDATE methods in Postman.
#
# ## Show the JSON response data for 200 success conditions on GET, POST, and UPDATE methods in Postman.

# %% [markdown]
# <img width="759" alt="Screenshot 2024-04-23 at 10 39 18 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/36d1dcca-bdf9-43e6-a5d0-c353507fc45b">

# %% [markdown]
# <img width="669" alt="Screenshot 2024-04-23 at 11 00 12 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/3149b270-6570-4f64-a6b0-7099df27401b">

# %% [markdown]
# <img width="662" alt="Screenshot 2024-04-23 at 11 05 20 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/d6582d3f-9efe-4e29-b41a-79c3fed3906a">

# %% [markdown]
# ## Show the JSON response for error for 400 when missing body on a POST request in Postman.

# %% [markdown]
# <img width="664" alt="Screenshot 2024-04-24 at 10 42 03 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/afef2071-2ca3-49b4-98cd-c3878fe0c64c">

# %% [markdown]
# <img width="663" alt="Screenshot 2024-04-23 at 11 17 46 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/05bd168f-c55f-436c-95eb-ea17b03b0322">

# %% [markdown]
# # Show the JSON response for error for 404 when providing an unknown user ID to a UPDATE request in Postman.

# %% [markdown]
# <img width="708" alt="Screenshot 2024-04-24 at 10 56 56 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/283b7b88-e152-4923-a0b4-3a87a9af4936">

# %% [markdown]
# ## Frontend

# %% [markdown]
# - Blog JavaScript API fetch code and formatting code to display JSON.

# %% [markdown]
# <img width="488" alt="Screenshot 2024-04-21 at 8 47 40 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/c1fb2d45-1aca-4e05-88c6-d539605b35e8">

# %% [markdown]
# - The code preforms a API fetch request to retrieve college data from a local server. After making the request, it processes the JSON response, and uses the data to update and display college search results on the web page, and logs the information to the console. If there's an error during the fetch, it catches and logs the error.

# %% [markdown]
# ## Show response of JSON objects from fetch of GET, POST, and UPDATE methods in Chrome inspect.

# %% [markdown]
# <img width="726" alt="Screenshot 2024-04-21 at 8 45 13 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/05e07f60-5068-4cd9-843c-55ddb79a5345">

# %% [markdown]
# - Get request
#     - This fetch request gets data from the database based ont he colleges id. In this example, every college is fetched. The method returns the JSON object as a python dictionary.

# %% [markdown]
# <img width="724" alt="Screenshot 2024-04-21 at 8 57 13 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/2f3c32a3-9a65-4ce2-9435-045f0712bcd8">

# %% [markdown]
# - Post request

# %% [markdown]
# <img width="594" alt="Screenshot 2024-04-21 at 9 19 03 PM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/42d38d3d-5a86-4849-8412-1873263d64bf">

# %% [markdown]
# - Update Request

# %% [markdown]
# ## Show a demo (GET) of obtaining an Array of JSON objects that are formatted into the browsers screen in the Chrome browser.

# %% [markdown]
# <img width="1363" alt="Screenshot 2024-04-24 at 11 22 15 AM" src="https://github.com/PatrickHastings2/tri3repo/assets/142462286/d7cb7750-3df4-44ee-8fb1-7d08a63ab127">

# %% [markdown]
# - The console on the right shows an array of university names, indicating these the data fetched from the server to populate the "Safety Schools" list

# %% [markdown]
# <iframe src="https://drive.google.com/file/d/1DBX19i9iE_N7egVyAxjnrV7ur92VyN91/preview" width="640" height="480" allow="autoplay"></iframe>

# %% [markdown]
# <iframe src="https://drive.google.com/file/d/1q9nN7sVXaPHuPga7aT0sodAaIa_Kcl42/preview" width="640" height="480" allow="autoplay"></iframe>
